# %%
# %load_ext autoreload
# %autoreload 2

# %%
import TSatPyViz
from TSatPy import State

# %%
q = State.Quaternion([0.3,0.1,1], radians=-1)

# %%
TSatPyViz.show(q)
# Out:
# Quaternion
# 	<Quaternion [0.137134 0.0457114 0.457114], 0.877583>
# Help on Text3D in module mpl_toolkits.mplot3d.art3d object:
#
# class Text3D(matplotlib.text.Text)
#  |  Text object with 3D position and (in the future) direction.
#  |
#  |  Method resolution order:
#  |      Text3D
#  |      matplotlib.text.Text
#  |      matplotlib.artist.Artist
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, x=0, y=0, z=0, text='', zdir='z', **kwargs)
#  |      *x*, *y*, *z*  Position of text
#  |      *text*         Text string to display
#  |      *zdir*         Direction of text
#  |
#  |      Keyword arguments are passed onto :func:`~matplotlib.text.Text`.
#  |
#  |  draw(self, renderer)
#  |
#  |  set_3d_properties(self, z=0, zdir='z')
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from matplotlib.text.Text:
#  |
#  |  __getstate__(self)
#  |
#  |  __str__(self)
#  |
# ...
